# %% [markdown]
# Goal for the CEO datasets we have in the data folder:
# - read this in python
# - check the dimension (rows, columns) of the data
# - check the names of the variables in every dataset. If needed, fix the columns names
# - Identify if we have any missing data
# - Look at the different data types
# - Anything else?
# - Save this cleaned dataset

# %%
# import libraries

import pandas as pd  # we use this for reading and writing data
import numpy as np # you will see why we use this shortly

# %% [markdown]
# ### CEO Data

# %%
# read the data file called CEO data.xlsx

pd.read_excel("../data/raw/CEO data.xlsx")
# Out:
#                Unnamed: 0                         Unnamed: 1  \
# 0      Annual Report Year                             Sector
# 1     2009-01-01 00:00:00                  General Retailers
# 2     2009-01-01 00:00:00                  General Retailers
# 3     2009-01-01 00:00:00            Engineering & Machinery
# 4     2009-01-01 00:00:00                  General Retailers
# ...                   ...                                ...
# 1812  2015-12-01 00:00:00  Construction & Building Materials
# 1813  2015-12-01 00:00:00                  Business Services
# 1814  2015-12-01 00:00:00                          Insurance
# 1815  2015-12-01 00:00:00                             Mining
# 1816  2015-12-01 00:00:00                             Mining
#
#                                              Unnamed: 2      Unnamed: 3  \
# 0                                          Company Name  Company Ticker
# 1                                         TED BAKER PLC             TED
# ...

# %%
# store this data as a variabel called CEO_data

CEO_data = pd.read_excel("../data/raw/CEO data.xlsx")

# %%
# preview the first five rows of the data

CEO_data.head()
# Out:
#             Unnamed: 0               Unnamed: 1  \
# 0   Annual Report Year                   Sector
# 1  2009-01-01 00:00:00        General Retailers
# 2  2009-01-01 00:00:00        General Retailers
# 3  2009-01-01 00:00:00  Engineering & Machinery
# 4  2009-01-01 00:00:00        General Retailers
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                       Company Name  Company Ticker
# 1                                      TED BAKER PLC             TED
# 2                                           NEXT PLC             NXT
# 3  MORGAN ADVANCED MATERIALS PLC (Morgan Crucible...            MGAM
# 4                                     KINGFISHER PLC             KGF
#
#        Unnamed: 4                                 Unnamed: 5  \
# 0   Company Index                            Individual Name
# 1   FTSE 250(GBP)                Raymond (Ray) Stuart Kelvin
# 2  FTSE 100 (GBP)  Lord (Simon Adam) Wolfson of Aspley Guise
# ...

# %%
# to check the type of the variable

type(CEO_data)

# A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns
# much like a spreadsheet. DataFrames are one of the most common data structures used in modern data analytics 
# because they are a flexible and intuitive way of storing and working with data.
# Out:
# pandas.core.frame.DataFrame

# %%
# check the shape of the data

CEO_data.shape
# Out:
# (1817, 22)

# %%
# what are your initial thoughts when looking at this data?
# headings look corrupt, so lets fix this

# the first row looks like the headings, so let's select the first row of the data

CEO_data.loc[0]
# Out:
# Unnamed: 0                                    Annual Report Year
# Unnamed: 1                                                Sector
# Unnamed: 2                                          Company Name
# Unnamed: 3                                        Company Ticker
# Unnamed: 4                                         Company Index
# Unnamed: 5                                       Individual Name
# Characteristics of Roles                         Individual Role
# Unnamed: 7                                          Time in Role
# Unnamed: 8                                             Age (Yrs)
# Unnamed: 9                              Number of Qualifications
# Unnamed: 10                                               Gender
# Unnamed: 11                                      Nationality Mix
# Annual Direct Compensation                                Salary
# Unnamed: 13                                                Bonus
# ...

# %%
# change the column names

CEO_data.columns = list(CEO_data.loc[0])

# %%
# preview the data

CEO_data.head()

# looks neater now, right?!
# Out:
#     Annual Report Year                   Sector  \
# 0   Annual Report Year                   Sector
# 1  2009-01-01 00:00:00        General Retailers
# 2  2009-01-01 00:00:00        General Retailers
# 3  2009-01-01 00:00:00  Engineering & Machinery
# 4  2009-01-01 00:00:00        General Retailers
#
#                                         Company Name  Company Ticker  \
# 0                                       Company Name  Company Ticker
# 1                                      TED BAKER PLC             TED
# 2                                           NEXT PLC             NXT
# 3  MORGAN ADVANCED MATERIALS PLC (Morgan Crucible...            MGAM
# 4                                     KINGFISHER PLC             KGF
#
#     Company Index                            Individual Name  Individual Role  \
# 0   Company Index                            Individual Name  Individual Role
# 1   FTSE 250(GBP)                Raymond (Ray) Stuart Kelvin              CEO
# ...

# %%
# drop the first rows of data

CEO_data.drop(index=0)
# Out:
#        Annual Report Year                             Sector  \
# 1     2009-01-01 00:00:00                  General Retailers
# 2     2009-01-01 00:00:00                  General Retailers
# 3     2009-01-01 00:00:00            Engineering & Machinery
# 4     2009-01-01 00:00:00                  General Retailers
# 5     2009-01-01 00:00:00                  General Retailers
# ...                   ...                                ...
# 1812  2015-12-01 00:00:00  Construction & Building Materials
# 1813  2015-12-01 00:00:00                  Business Services
# 1814  2015-12-01 00:00:00                          Insurance
# 1815  2015-12-01 00:00:00                             Mining
# 1816  2015-12-01 00:00:00                             Mining
#
#                                            Company Name Company Ticker  \
# 1                                         TED BAKER PLC            TED
# 2                                              NEXT PLC            NXT
# ...

# %%
# save this as a new variable

CEO_data_cleaned = CEO_data.drop(index=0)

# %%
# preview the CEO_data_cleaned

pd.set_option('display.max_columns', 500) # you can use this to view all columns

CEO_data_cleaned.head()
# Out:
#     Annual Report Year                   Sector  \
# 1  2009-01-01 00:00:00        General Retailers
# 2  2009-01-01 00:00:00        General Retailers
# 3  2009-01-01 00:00:00  Engineering & Machinery
# 4  2009-01-01 00:00:00        General Retailers
# 5  2009-01-01 00:00:00        General Retailers
#
#                                         Company Name Company Ticker  \
# 1                                      TED BAKER PLC            TED
# 2                                           NEXT PLC            NXT
# 3  MORGAN ADVANCED MATERIALS PLC (Morgan Crucible...           MGAM
# 4                                     KINGFISHER PLC            KGF
# 5  JD SPORTS FASHION PLC (John David Group prior ...            JD.
#
#     Company Index                            Individual Name Individual Role  \
# 1   FTSE 250(GBP)                Raymond (Ray) Stuart Kelvin             CEO
# 2  FTSE 100 (GBP)  Lord (Simon Adam) Wolfson of Aspley Guise             CEO
# ...

# %%
# compare the shape between CEO_data and CEO_data_cleaned

print(CEO_data.shape)
print(CEO_data_cleaned.shape)

# what is the difference between the two dataframes?
# Out:
# (1817, 22)
# (1816, 22)

# %%
# check for missing data

CEO_data_cleaned.isnull().sum()

# hmm.. the 0 means that there is no missing data. Keep note.
# Out:
# Annual Report Year                   0
# Sector                               0
# Company Name                         0
# Company Ticker                       0
# Company Index                        0
# Individual Name                      0
# Individual Role                      0
# Time in Role                         0
# Age (Yrs)                            0
# Number of Qualifications             0
# Gender                               0
# Nationality Mix                      0
# Salary                               0
# Bonus                                0
# D.C Pension                          0
# Other                                0
# Total Salary+Bonus                   0
# Total Inc. D.C. Pension & Other      0
# Total Equity Linked Compensation     0
# Total Annual Compensation            0
# Liquid Wealth                        0
# Total Wealth                         0
# dtype: int64

# %%
# Structure of the data

CEO_data_cleaned.info()

# which data types need fixing? Dtypes object are non numerical data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 1 to 1816
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Annual Report Year                 1816 non-null   object
#  1   Sector                             1816 non-null   object
#  2   Company Name                       1816 non-null   object
#  3   Company Ticker                     1816 non-null   object
#  4   Company Index                      1816 non-null   object
#  5   Individual Name                    1816 non-null   object
#  6   Individual Role                    1816 non-null   object
#  7   Time in Role                       1816 non-null   object
#  8   Age (Yrs)                          1816 non-null   object
#  9   Number of Qualifications           1816 non-null   object
#  10  Gender                             1816 non-null   object
# ...

# %%
# let's see if we can figure out why Age is being picked up as a data type object

CEO_data_cleaned["Age (Yrs)"].value_counts()
# Out:
# 53     126
# 52     126
# 51     123
# 50     118
# 54     116
# 49     115
# 55     104
# 56     102
# 48      96
# 57      87
# 47      86
# 58      73
# 46      71
# 59      62
# 45      51
# 44      46
# 60      42
# 43      36
# 61      27
# 42      26
# 62      24
# 63      23
# 41      21
# 40      17
# 39      12
# 64      11
# 38       9
# 65       8
# 37       6
# 66       6
# 67       5
# n.a      5
# 36       4
# 69       3
# 71       3
# 75       3
# 70       3
# 73       3
# 72       3
# 74       3
# 35       2
# 76       2
# 34       2
# 68       2
# 77       1
# 78       1
# 79       1
# Name: Age (Yrs), dtype: int64

# %%
CEO_data_cleaned[CEO_data_cleaned["Age (Yrs)"] == "n.a"]
# Out:
#        Annual Report Year            Sector         Company Name  \
# 221   2009-12-01 00:00:00  Leisure & Hotels  CINEWORLD GROUP PLC
# 469   2010-12-01 00:00:00  Leisure & Hotels  CINEWORLD GROUP PLC
# 724   2011-12-01 00:00:00  Leisure & Hotels  CINEWORLD GROUP PLC
# 984   2012-12-01 00:00:00  Leisure & Hotels  CINEWORLD GROUP PLC
# 1252  2013-12-01 00:00:00  Leisure & Hotels  CINEWORLD GROUP PLC
#
#      Company Ticker  Company Index              Individual Name  \
# 221            CINE  FTSE 250(GBP)  Stephen (Steve) Mark Wiener
# 469            CINE  FTSE 250(GBP)  Stephen (Steve) Mark Wiener
# 724            CINE  FTSE 250(GBP)  Stephen (Steve) Mark Wiener
# 984            CINE  FTSE 250(GBP)  Stephen (Steve) Mark Wiener
# 1252           CINE  FTSE 250(GBP)  Stephen (Steve) Mark Wiener
#
#      Individual Role Time in Role Age (Yrs) Number of Qualifications Gender  \
# 221              CEO          2.7       n.a                        0      M
# ...

# %%
# instead of going through every column individually we can use a bit of python code to replace the "n.a" 
# with something python will recognise

print(np.nan)
# Out:
# nan

# %%
CEO_data_cleaned = CEO_data_cleaned.replace('n.a', np.nan)

# %%
# check the structure of the data after replacing na

CEO_data_cleaned.info()

# Anything else??
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 1 to 1816
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Annual Report Year                 1816 non-null   datetime64[ns]
#  1   Sector                             1816 non-null   object
#  2   Company Name                       1816 non-null   object
#  3   Company Ticker                     1816 non-null   object
#  4   Company Index                      1816 non-null   object
#  5   Individual Name                    1816 non-null   object
#  6   Individual Role                    1816 non-null   object
#  7   Time in Role                       1816 non-null   float64
#  8   Age (Yrs)                          1811 non-null   float64
#  9   Number of Qualifications           1816 non-null   int64
#  10  Gender                             1816 non-null   object
# ...

# %%
# save the cleaned dataset into the data folder

CEO_data_cleaned.to_excel("../data/cleaned/CEO_data_cleaned.xlsx")

# %% [markdown]
# Feel free to open this as an excel file, or use this notebook. What would you like to analyse when working with this data?
