# %%
# import libraries we will work with today

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read cleaned data

ceo_data = pd.read_excel("../data/cleaned/CEO_data_cleaned.xlsx")

# %%
# code to drop this unnamed column if you want to

ceo_data.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
# preview data
# if you see an unamed column, there was a mistake when saving the data 
# add index = False to the to_excel function

ceo_data.head()
# Out:
#   Annual Report Year                   Sector
# 0         2009-01-01        General Retailers  \
# 1         2009-01-01        General Retailers
# 2         2009-01-01  Engineering & Machinery
# 3         2009-01-01        General Retailers
# 4         2009-01-01        General Retailers
#
#                                         Company Name Company Ticker
# 0                                      TED BAKER PLC            TED  \
# 1                                           NEXT PLC            NXT
# 2  MORGAN ADVANCED MATERIALS PLC (Morgan Crucible...           MGAM
# 3                                     KINGFISHER PLC            KGF
# 4  JD SPORTS FASHION PLC (John David Group prior ...            JD.
#
#     Company Index                            Individual Name Individual Role
# 0   FTSE 250(GBP)                Raymond (Ray) Stuart Kelvin             CEO  \
# 1  FTSE 100 (GBP)  Lord (Simon Adam) Wolfson of Aspley Guise             CEO
# 2   FTSE 250(GBP)                            Mark Robertshaw             CEO
# 3  FTSE 100 (GBP)                   Sir Ian Michael Cheshire       Group CEO
# 4   FTSE 250(GBP)                           Barry Colin Bown             CEO
#
#    Time in Role  Age (Yrs)  Number of Qualifications  ... Salary  Bonus
# 0          21.0       53.0                         0  ...    272    0.0  \
# 1           7.4       41.0                         2  ...    675  123.0
# 2           2.4       40.0                         1  ...    440  264.0
# 3           1.0       49.0                         2  ...    800  802.0
# 4           8.5       47.0                         0  ...    283  285.0
#
#    D.C Pension  Other  Total Salary+Bonus  Total Inc. D.C. Pension & Other
# 0          NaN   11.0                 272                              283  \
# 1          NaN   33.0                 798                              831
# 2        108.0   13.0                 704                              825
# 3        205.0   35.0                1602                             1842
# 4         22.0  301.0                 568                              891
#
#    Total Equity Linked Compensation   Total Annual Compensation
# 0                              721.0                         993  \
# 1                             1581.0                        2379
# 2                              781.0                        1485
# 3                               35.0                        1637
# 4                                NaN                         568
#
#    Liquid Wealth  Total Wealth
# 0        57467.0       58514.0
# 1        17597.0       19531.0
# 2          405.0        2666.0
# 3          522.0        4733.0
# 4           12.0         260.0
#
# [5 rows x 22 columns]

# %%
pd.set_option('display.max_columns', 500) # you can use this to view all columns

ceo_data.head()
# Out:
#   Annual Report Year                   Sector
# 0         2009-01-01        General Retailers  \
# 1         2009-01-01        General Retailers
# 2         2009-01-01  Engineering & Machinery
# 3         2009-01-01        General Retailers
# 4         2009-01-01        General Retailers
#
#                                         Company Name Company Ticker
# 0                                      TED BAKER PLC            TED  \
# 1                                           NEXT PLC            NXT
# 2  MORGAN ADVANCED MATERIALS PLC (Morgan Crucible...           MGAM
# 3                                     KINGFISHER PLC            KGF
# 4  JD SPORTS FASHION PLC (John David Group prior ...            JD.
#
#     Company Index                            Individual Name Individual Role
# 0   FTSE 250(GBP)                Raymond (Ray) Stuart Kelvin             CEO  \
# 1  FTSE 100 (GBP)  Lord (Simon Adam) Wolfson of Aspley Guise             CEO
# 2   FTSE 250(GBP)                            Mark Robertshaw             CEO
# 3  FTSE 100 (GBP)                   Sir Ian Michael Cheshire       Group CEO
# 4   FTSE 250(GBP)                           Barry Colin Bown             CEO
#
#    Time in Role  Age (Yrs)  Number of Qualifications Gender Nationality Mix
# 0          21.0       53.0                         0      M         British  \
# 1           7.4       41.0                         2      M         British
# 2           2.4       40.0                         1      M         British
# 3           1.0       49.0                         2      M         British
# 4           8.5       47.0                         0      M         British
#
#    Salary  Bonus  D.C Pension  Other  Total Salary+Bonus
# 0     272    0.0          NaN   11.0                 272  \
# 1     675  123.0          NaN   33.0                 798
# 2     440  264.0        108.0   13.0                 704
# 3     800  802.0        205.0   35.0                1602
# 4     283  285.0         22.0  301.0                 568
#
#    Total Inc. D.C. Pension & Other  Total Equity Linked Compensation
# 0                              283                              721.0  \
# 1                              831                             1581.0
# 2                              825                              781.0
# 3                             1842                               35.0
# 4                              891                                NaN
#
#    Total Annual Compensation   Liquid Wealth  Total Wealth
# 0                         993        57467.0       58514.0
# 1                        2379        17597.0       19531.0
# 2                        1485          405.0        2666.0
# 3                        1637          522.0        4733.0
# 4                         568           12.0         260.0

# %%
# remind yourself... how big is the data set

ceo_data.shape
# Out:
# (1816, 22)

# %%
# remind yourself the different fields in the data sets

ceo_data.info()

# Let's start by exploring the variables with data type object and datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Annual Report Year                 1816 non-null   datetime64[ns]
#  1   Sector                             1816 non-null   object
#  2   Company Name                       1816 non-null   object
#  3   Company Ticker                     1816 non-null   object
#  4   Company Index                      1816 non-null   object
#  5   Individual Name                    1816 non-null   object
#  6   Individual Role                    1816 non-null   object
#  7   Time in Role                       1816 non-null   float64
#  8   Age (Yrs)                          1811 non-null   float64
#  9   Number of Qualifications           1816 non-null   int64
#  10  Gender                             1816 non-null   object
#  11  Nationality Mix                    1769 non-null   object
#  12  Salary                             1816 non-null   int64
#  13  Bonus                              1793 non-null   float64
#  14  D.C Pension                        1339 non-null   float64
#  15  Other                              1764 non-null   float64
#  16  Total Salary+Bonus                 1816 non-null   int64
#  17  Total Inc. D.C. Pension & Other    1816 non-null   int64
#  18  Total Equity Linked Compensation   1545 non-null   float64
#  19  Total Annual Compensation          1816 non-null   int64
#  20  Liquid Wealth                      1705 non-null   float64
#  21  Total Wealth                       1784 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(5), object(8)
# memory usage: 312.3+ KB

# %%
# for reference -- the variables we are going to explore

list(ceo_data.select_dtypes(["float64", "int64"]).columns)
# Out:
# ['Time in Role',
#  'Age (Yrs)',
#  'Number of Qualifications',
#  'Salary',
#  'Bonus',
#  'D.C Pension',
#  'Other',
#  'Total Salary+Bonus',
#  'Total Inc. D.C. Pension & Other',
#  'Total Equity Linked Compensation ',
#  'Total Annual Compensation ',
#  'Liquid Wealth',
#  'Total Wealth']

# %%
# we can use the describe function that gives us summary statistics for all numerical variables

pd.set_option('display.float_format', lambda x: '%.5f' % x) # fix the display

ceo_data.describe()

# handy function but can feel very overwhelming
# Out:
#                   Annual Report Year  Time in Role  Age (Yrs)
# count                           1816    1816.00000 1811.00000  \
# mean   2012-09-22 00:00:47.577092608       5.73265   52.13031
# min              2009-01-01 00:00:00       0.00000   34.00000
# 25%              2010-12-01 00:00:00       1.90000   48.00000
# 50%              2012-12-01 00:00:00       4.30000   52.00000
# 75%              2014-06-01 00:00:00       7.50000   56.00000
# max              2015-12-01 00:00:00      39.40000   79.00000
# std                              NaN       5.60054    6.20342
#
#        Number of Qualifications     Salary      Bonus  D.C Pension
# count                1816.00000 1816.00000 1793.00000   1339.00000  \
# mean                    1.79956  588.21090  574.95594    153.41449
# min                     0.00000   12.00000    0.00000      1.00000
# 25%                     1.00000  415.75000  158.00000     54.00000
# 50%                     2.00000  530.00000  420.00000    110.00000
# 75%                     2.00000  748.25000  750.00000    189.00000
# max                     6.00000 2213.00000 7900.00000   8355.00000
# std                     1.13036  271.07851  672.43220    279.86727
#
#             Other  Total Salary+Bonus  Total Inc. D.C. Pension & Other
# count  1764.00000          1816.00000                       1816.00000  \
# mean    131.05442          1155.87335                       1396.28469
# min       0.00000            15.00000                         16.00000
# 25%      16.00000           636.75000                        751.50000
# 50%      27.00000           950.00000                       1107.50000
# 75%      59.25000          1424.25000                       1681.00000
# max   73784.00000          8400.00000                      74875.00000
# std    1774.57659           800.46408                       1971.58784
#
#        Total Equity Linked Compensation   Total Annual Compensation
# count                         1545.00000                  1816.00000  \
# mean                          2076.04142                  2922.10518
# min                              0.00000                    15.00000
# 25%                            666.00000                  1172.75000
# 50%                           1261.00000                  2090.00000
# 75%                           2389.00000                  3633.00000
# max                          64755.00000                 65930.00000
# std                           2979.98992                  3246.05503
#
#        Liquid Wealth  Total Wealth
# count     1705.00000    1784.00000
# mean     39429.60059   43791.53868
# min          1.00000      17.00000
# 25%        792.00000    3175.25000
# 50%       2566.00000    7253.00000
# 75%       7657.00000   17095.25000
# max    4286202.00000 4286202.00000
# std     213482.72241  208975.28361

# %%
print("Average Time in Roles of the CEO", round(ceo_data["Time in Role"].mean(), 2))
print("Average Age of the CEO", round(ceo_data["Age (Yrs)"].mean(), 2))
print("Average Qualifications of the CEO", round(ceo_data["Number of Qualifications"].mean(), 2))
print("Average Salary of the CEO", round(ceo_data["Salary"].mean()*1000, 2))
print("Average Compensation of the CEO", round(ceo_data["Total Annual Compensation "].mean()*1000, 2))

# should have cleaned the column name in our data cleaning
# Out:
# Average Time in Roles of the CEO 5.73
# Average Age of the CEO 52.13
# Average Qualifications of the CEO 1.8
# Average Salary of the CEO 588210.9
# Average Compensation of the CEO 2922105.18

# %%
ceo_data.rename({'Total Annual Compensation ': 'Total Annual Compensation'}, axis=1, inplace = True)

# %%
print("Median Time in Roles of the CEO", round(ceo_data["Time in Role"].median(), 2))
print("Median Age of the CEO", round(ceo_data["Age (Yrs)"].median(), 2))
print("Median Qualifications of the CEO", round(ceo_data["Number of Qualifications"].median(), 2))
print("Median Salary of the CEO", round(ceo_data["Salary"].median(), 2))
print("Median Compensation of the CEO", round(ceo_data["Total Annual Compensation"].median(), 2))

# Time of Role and Average Salary have varying mean and median
# Out:
# Median Time in Roles of the CEO 4.3
# Median Age of the CEO 52.0
# Median Qualifications of the CEO 2.0
# Median Salary of the CEO 530.0
# Median Compensation of the CEO 2090.0

# %%
# before we investigate further, remember there are multiple rows of data for the same CEO
# should we double check if these values change

print("Average Time in Roles of the CEO:", round(ceo_data.groupby(["Individual Name"])["Time in Role"].mean().mean(), 2))
print("Average Age of the CEO:", round(ceo_data.groupby(["Individual Name"])["Age (Yrs)"].mean().mean(), 2))
print("Average Qualifications of the CEO:", round(ceo_data.groupby(["Individual Name"])["Number of Qualifications"].mean().mean(), 2))
print("Average Salary of the CEO:", round(ceo_data.groupby(["Individual Name"])["Salary"].mean().mean()*1000, 2))
print("Average Compensation of the CEO:", round(ceo_data.groupby(["Individual Name"])["Total Annual Compensation"].mean().mean()*1000, 2))

# Aside from time in roles, the values do not change so much so we dont to aggregrate the data
# Out:
# Average Time in Roles of the CEO: 4.74
# Average Age of the CEO: 52.51
# Average Qualifications of the CEO: 1.77
# Average Salary of the CEO: 584684.78
# Average Compensation of the CEO: 2858529.73

# %%
# is there a relationship between age and salary?

sns.scatterplot(x ="Age (Yrs)", y="Salary", data=ceo_data)
plt.title("Relationship between Age and Salary");

# %%
# hue can be used if you want to represent the data points by a specific group

sns.scatterplot(x ="Age (Yrs)", y="Salary", data=ceo_data, hue="Gender")
plt.title("Relationship between Age and Salary with Gender");

# %%
# Plot a scatter plot 
# - is there a relationship between time in role and salary?

sns.scatterplot(x ="Time in Role", y="Salary", data=ceo_data)
plt.title("Relationship between Time in Role and Salary");

# %%
# Plot a scatter plot 
# - is there a relationship between number of qualifications and salary?

sns.scatterplot(x ="Number of Qualifications", y="Salary", data=ceo_data)
plt.title("Relationship between Number of Qualifications and Salary");

# %%
# A lot of working going through all the variables and plotting scatter plots
# best way to understand the relationship between all the different numerical variables is with a correlation matrix

corr_matrix = ceo_data.corr(numeric_only = True)
corr_matrix

# A scatterplot displays the strength, direction, and form of the relationship between two quantitative variables. 
# A correlation coefficient measures the strength of that relationship.

# Which variables have the highest correlation?
# Out:
#                                    Time in Role  Age (Yrs)
# Time in Role                            1.00000    0.37231  \
# Age (Yrs)                               0.37231    1.00000
# Number of Qualifications                0.01657    0.06302
# Salary                                 -0.03617    0.14241
# Bonus                                   0.09690    0.08763
# D.C Pension                             0.01061    0.12114
# Other                                   0.02384    0.03880
# Total Salary+Bonus                      0.06406    0.11619
# Total Inc. D.C. Pension & Other         0.04296    0.09181
# Total Equity Linked Compensation        0.01151    0.06608
# Total Annual Compensation               0.00962    0.07610
# Liquid Wealth                           0.10640    0.07837
# Total Wealth                            0.11211    0.08337
#
#                                    Number of Qualifications   Salary   Bonus
# Time in Role                                        0.01657 -0.03617 0.09690  \
# Age (Yrs)                                           0.06302  0.14241 0.08763
# Number of Qualifications                            1.00000  0.17034 0.05987
# Salary                                              0.17034  1.00000 0.32809
# Bonus                                               0.05987  0.32809 1.00000
# D.C Pension                                         0.06413  0.37966 0.15204
# Other                                               0.00737  0.02279 0.01269
# Total Salary+Bonus                                  0.10652  0.60756 0.94761
# Total Inc. D.C. Pension & Other                     0.05846  0.30438 0.40935
# Total Equity Linked Compensation                    0.08898  0.40112 0.39741
# Total Annual Compensation                           0.11542  0.46947 0.52030
# Liquid Wealth                                       0.00630  0.04407 0.09030
# Total Wealth                                        0.01101  0.06240 0.13257
#
#                                    D.C Pension    Other  Total Salary+Bonus
# Time in Role                           0.01061  0.02384             0.06406  \
# Age (Yrs)                              0.12114  0.03880             0.11619
# Number of Qualifications               0.06413  0.00737             0.10652
# Salary                                 0.37966  0.02279             0.60756
# Bonus                                  0.15204  0.01269             0.94761
# D.C Pension                            1.00000  0.05394             0.25134
# Other                                  0.05394  1.00000             0.01862
# Total Salary+Bonus                     0.25134  0.01862             1.00000
# Total Inc. D.C. Pension & Other        0.51337  0.89707             0.44703
# Total Equity Linked Compensation       0.12593  0.00392             0.45529
# Total Annual Compensation              0.17978  0.01079             0.59185
# Liquid Wealth                         -0.03677 -0.00864             0.02428
# Total Wealth                          -0.02911 -0.00861             0.05014
#
#                                    Total Inc. D.C. Pension & Other
# Time in Role                                               0.04296  \
# Age (Yrs)                                                  0.09181
# Number of Qualifications                                   0.05846
# Salary                                                     0.30438
# Bonus                                                      0.40935
# D.C Pension                                                0.51337
# Other                                                      0.89707
# Total Salary+Bonus                                         0.44703
# Total Inc. D.C. Pension & Other                            1.00000
# Total Equity Linked Compensation                           0.17909
# Total Annual Compensation                                  0.27083
# Liquid Wealth                                             -0.00447
# Total Wealth                                               0.00703
#
#                                    Total Equity Linked Compensation
# Time in Role                                                 0.01151  \
# Age (Yrs)                                                    0.06608
# Number of Qualifications                                     0.08898
# Salary                                                       0.40112
# Bonus                                                        0.39741
# D.C Pension                                                  0.12593
# Other                                                        0.00392
# Total Salary+Bonus                                           0.45529
# Total Inc. D.C. Pension & Other                              0.17909
# Total Equity Linked Compensation                             1.00000
# Total Annual Compensation                                    0.98106
# Liquid Wealth                                                0.03421
# Total Wealth                                                 0.12502
#
#                                    Total Annual Compensation  Liquid Wealth
# Time in Role                                         0.00962        0.10640  \
# Age (Yrs)                                            0.07610        0.07837
# Number of Qualifications                             0.11542        0.00630
# Salary                                               0.46947        0.04407
# Bonus                                                0.52030        0.09030
# D.C Pension                                          0.17978       -0.03677
# Other                                                0.01079       -0.00864
# Total Salary+Bonus                                   0.59185        0.02428
# Total Inc. D.C. Pension & Other                      0.27083       -0.00447
# Total Equity Linked Compensation                     0.98106        0.03421
# Total Annual Compensation                            1.00000       -0.03744
# Liquid Wealth                                       -0.03744        1.00000
# Total Wealth                                        -0.00008        0.99857
#
#                                    Total Wealth
# Time in Role                            0.11211
# Age (Yrs)                               0.08337
# Number of Qualifications                0.01101
# Salary                                  0.06240
# Bonus                                   0.13257
# D.C Pension                            -0.02911
# Other                                  -0.00861
# Total Salary+Bonus                      0.05014
# Total Inc. D.C. Pension & Other         0.00703
# Total Equity Linked Compensation        0.12502
# Total Annual Compensation              -0.00008
# Liquid Wealth                           0.99857
# Total Wealth                            1.00000

# %%
# option 1 

corr_matrix.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c9c31_row0_col0, #T_c9c31_row1_col1, #T_c9c31_row2_col2, #T_c9c31_row3_col3, #T_c9c31_row4_col4, #T_c9c31_row5_col5, #T_c9c31_row6_col6, #T_c9c31_row7_col7, #T_c9c31_row8_col8, #T_c9c31_row9_col9, #T_c9c31_row10_col10, #T_c9c31_row11_col11, #T_c9c31_row11_col12, #T_c9c31_row12_col11, #T_c9c31_row12_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c9c31_row0_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_c9c31_row0_col2, #T_c9c31_row12_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c9c31_row0_col3, #T_c9c31_row3_col0, #T_c9c31_row5_col11, #T_c9c31_row5_col12, #T_c9c31_row6_col1, #T_c9c31_row6_col2, #T_c9c31_row6_col4, #T_c9c31_row6_col7, #T_c9c31_row6_col9, #T_c9c31_row10_col11, #T_c9c31_row11_col2, #T_c9c31_row11_col5, #T_c9c31_row11_col6, #T_c9c31_row11_col8, #T_c9c31_row11_col10, #T_c9c31_row12_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c9c31_row0_col4, #T_c9c31_row2_col9, #T_c9c31_row5_col1, #T_c9c31_row9_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_c9c31_row0_col5, #T_c9c31_row0_col7, #T_c9c31_row0_col8, #T_c9c31_row0_col10, #T_c9c31_row1_col6, #T_c9c31_row2_col4, #T_c9c31_row5_col0, #T_c9c31_row6_col10, #T_c9c31_row9_col0, #T_c9c31_row10_col0, #T_c9c31_row12_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c9c31_row0_col6, #T_c9c31_row8_col11, #T_c9c31_row8_col12, #T_c9c31_row12_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_c9c31_row0_col9, #T_c9c31_row11_col7, #T_c9c31_row12_col2, #T_c9c31_row12_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c9c31_row0_col11, #T_c9c31_row0_col12, #T_c9c31_row11_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_c9c31_row1_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_c9c31_row1_col2, #T_c9c31_row5_col2, #T_c9c31_row6_col0, #T_c9c31_row6_col3, #T_c9c31_row8_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_c9c31_row1_col3 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_c9c31_row1_col4, #T_c9c31_row7_col12, #T_c9c31_row8_col0, #T_c9c31_row11_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_c9c31_row1_col5, #T_c9c31_row9_col12 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_c9c31_row1_col7, #T_c9c31_row7_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_c9c31_row1_col8, #T_c9c31_row2_col5, #T_c9c31_row7_col0, #T_c9c31_row12_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_c9c31_row1_col9, #T_c9c31_row5_col6, #T_c9c31_row7_col11 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_c9c31_row1_col10, #T_c9c31_row1_col11, #T_c9c31_row10_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_c9c31_row1_col12, #T_c9c31_row3_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c9c31_row2_col0, #T_c9c31_row4_col1, #T_c9c31_row4_col2, #T_c9c31_row8_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_c9c31_row2_col1, #T_c9c31_row7_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c9c31_row2_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_c9c31_row2_col6, #T_c9c31_row10_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c9c31_row2_col7, #T_c9c31_row3_col12, #T_c9c31_row6_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_c9c31_row2_col8 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c9c31_row2_col10 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_c9c31_row2_col11, #T_c9c31_row11_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_c9c31_row2_col12, #T_c9c31_row10_col1, #T_c9c31_row12_col10 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_c9c31_row3_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_c9c31_row3_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_c9c31_row3_col5, #T_c9c31_row3_col9, #T_c9c31_row5_col3, #T_c9c31_row8_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_c9c31_row3_col6, #T_c9c31_row6_col11, #T_c9c31_row9_col1, #T_c9c31_row10_col12, #T_c9c31_row11_col9 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_c9c31_row3_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c9c31_row3_col8 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_c9c31_row3_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_c9c31_row3_col11, #T_c9c31_row7_col1, #T_c9c31_row11_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_c9c31_row4_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_c9c31_row4_col3 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c9c31_row4_col5, #T_c9c31_row9_col8 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_c9c31_row4_col6, #T_c9c31_row6_col12 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_c9c31_row4_col7, #T_c9c31_row7_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_c9c31_row4_col8 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_c9c31_row4_col9 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_c9c31_row4_col10 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_c9c31_row4_col11, #T_c9c31_row5_col9, #T_c9c31_row12_col4, #T_c9c31_row12_col9 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_c9c31_row4_col12, #T_c9c31_row9_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_c9c31_row5_col4, #T_c9c31_row12_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_c9c31_row5_col7 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_c9c31_row5_col8, #T_c9c31_row10_col4 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_c9c31_row5_col10, #T_c9c31_row10_col5 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_c9c31_row6_col8, #T_c9c31_row8_col6 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_c9c31_row7_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_c9c31_row7_col5 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_c9c31_row7_col8 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_c9c31_row7_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c9c31_row7_col10 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_c9c31_row8_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_c9c31_row8_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_c9c31_row8_col7 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_c9c31_row8_col9 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_c9c31_row8_col10 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_c9c31_row9_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_c9c31_row9_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_c9c31_row9_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_c9c31_row9_col7 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_c9c31_row9_col10, #T_c9c31_row10_col9 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_c9c31_row9_col11 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c9c31_row10_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c9c31_row10_col7 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_c9c31_row10_col8 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# </style>
# <table id="T_c9c31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9c31_level0_col0" class="col_heading level0 col0" >Time in Role</th>
#       <th id="T_c9c31_level0_col1" class="col_heading level0 col1" >Age (Yrs)</th>
#       <th id="T_c9c31_level0_col2" class="col_heading level0 col2" >Number of Qualifications</th>
#       <th id="T_c9c31_level0_col3" class="col_heading level0 col3" >Salary</th>
#       <th id="T_c9c31_level0_col4" class="col_heading level0 col4" >Bonus</th>
#       <th id="T_c9c31_level0_col5" class="col_heading level0 col5" >D.C Pension</th>
#       <th id="T_c9c31_level0_col6" class="col_heading level0 col6" >Other</th>
#       <th id="T_c9c31_level0_col7" class="col_heading level0 col7" >Total Salary+Bonus</th>
#       <th id="T_c9c31_level0_col8" class="col_heading level0 col8" >Total Inc. D.C. Pension & Other</th>
#       <th id="T_c9c31_level0_col9" class="col_heading level0 col9" >Total Equity Linked Compensation </th>
#       <th id="T_c9c31_level0_co

# %%
# option 2

plt.figure(figsize=(15, 10))

sns.heatmap(corr_matrix, 
            cmap="Blues", 
            linewidth=0.75,
            linecolor='white',
            # cbar=False,
            # cbar_kws={"orientation": "horizontal"},
            vmin=-1, 
            vmax=1,
            annot=True,
            annot_kws={"size": 10, "color": "white"}
           )

plt.title("CEO Data Correlation Plot", size=14)
plt.savefig("../plots/corr_plots.png");


# which variables are highly correlated?

# %%
# How does Salary vary by gender?
plt.figure(figsize=(3, 4))
sns.boxplot(x="Gender", y="Salary", data=ceo_data, palette="Set1")
plt.title("Salary by Gender");

# what conclusions can you draw?

# %%
# Does Time in Role vary by Gender?
sns.boxplot(x="Time in Role", y="Gender", data=ceo_data)
plt.title("Time in Role by Gender");

# %%
# How does Salary vary by nationality?

plt.figure(figsize=(35, 10))
sns.boxplot(y="Salary", x="Nationality Mix", data=ceo_data)
plt.tick_params(labelsize=12, rotation=0)
plt.title("Boxplots for Salaries Across Nationalities");

# %%
plt.figure(figsize=(35, 10))
sns.boxplot(y="Total Annual Compensation", x="Nationality Mix", data=ceo_data)
plt.tick_params(labelsize=12, rotation=0)
plt.title("Boxplots for Compensation Across Nationalities");

# %%
plt.figure(figsize=(35, 10))
sns.boxplot(y="Total Wealth", x="Nationality Mix", data=ceo_data)
plt.tick_params(labelsize=12, rotation=0)
plt.title("Boxplots for Compensation Across Nationalities");

# %%
# identify outliers
import numpy as np

def calc_ub_and_lb(df, var):
    """
    This function identifies the upper and lower bounds for a variable that you specify
    """
    
    q3 = np.nanpercentile(df[var], 75)
    q1 = np.nanpercentile(df[var], 25)
    iqr = q3 - q1
    ub = q3 + 1.5*iqr
    lb = q1 - 1.5*iqr
    
    print("The upper bound is", ub)
    print("The lower bound is", lb)
    
    return lb, ub

# %%
lb, ub = calc_ub_and_lb(ceo_data, "Total Wealth")
# Out:
# The upper bound is 37975.25
# The lower bound is -17704.75

# %%
ceo_data_wout_outtliers = ceo_data[ceo_data["Total Wealth"].between(lb, ub)]
print(ceo_data.shape)
print(ceo_data_wout_outtliers.shape)
# Out:
# (1816, 22)
# (1575, 22)

# %%
plt.figure(figsize=(35, 10))
sns.boxplot(y="Total Wealth", x="Nationality Mix", data=ceo_data_wout_outliers)
plt.tick_params(labelsize=12, rotation=0)
plt.title("Boxplots for Total Wealth Across Nationalities");

# %%
# How does the Salary vary by Sector?

# %%
# Anything else????

# %% [markdown]
# Summarise our explorations:
# - Some relationship between age and salary. We also visualised the scatter plots using "hue" which represents which category the data point belongs to.
# - NO Strong positive or negative correlations between our variables, aside from all the different salary metrics
# - We know our data is predemoninatly British CEOs but yay we have a Kazakstani CEO! We also noticed that CEOs from Chile earn a higher salary than other nationalities.
